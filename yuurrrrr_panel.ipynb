# %%
import panel as pn
import pandas as pd
import numpy as np

# %%
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1bf70941-759a-4f98-af05-907d46a93bd4'>
#   <div id="d618bf6f-3235-4087-bebe-7e1992730492" data-root-id="1bf70941-759a-4f98-af05-907d46a93bd4" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c4a36ce9-6bce-46cc-b548-dbc0fe558797":{"version":"3.3.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"1bf70941-759a-4f98-af05-907d46a93bd4"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"68d7fbd2-35b4-49ad-97cb-64b042e2cbee","attributes":{"plot_id":"1bf70941-759a-4f98-af05-907d46a93bd4","comm_id":"1fe6d424a2a64514b6349df39103a1e8","client_comm_id":"9e9b423296c04bcaa0a65570707069e5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"c4a36ce9-6bce-46cc-b548-dbc0fe558797","roots":{"1bf70941-759a-4f98-af05-907d46a93bd4":"d618bf6f-3235-4087-bebe-7e1992730492"},"root_ids":["1bf70941-759a-4f98-af05-907d46a93bd4"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
def render_print(x):
    return x*x

# %%
interactive_panel = pn.interact(render_print, x=5)

# %%
interactive_panel
# Out:
# Column
#     [0] Column
#         [0] IntSlider(end=15, name='x', start=-5, value=5)
#     [1] Row
#         [0] Str(int, name='interactive00198')

# %%
def nog_een_functie(y):
    return f"waarde is {y}"

foo = pn.interact(nog_een_functie, y = "henk")
foo
# Out:
# Column
#     [0] Column
#         [0] TextInput(name='y', value='henk')
#     [1] Row
#         [0] Markdown(str, name='interactive00256')

# %%
def another_function(a):
    return a

bar = pn.interact(another_function, a = False)
bar
# Out:
# Column
#     [0] Column
#         [0] Checkbox(name='a')
#     [1] Row
#         [0] Str(bool, name='interactive00314')

# %%
@pn.interact(x=True, y="Jantje")
def dingen(x, y):
    return x, y

dingen
# Out:
# Column
#     [0] Column
#         [0] Checkbox(name='x', value=True)
#         [1] TextInput(name='y', value='Jantje')
#     [1] Row
#         [0] Str(tuple, name='interactive00343')

# %%
print(interactive_panel)
# Out:
# Column
#     [0] Column
#         [0] IntSlider(end=15, name='x', start=-5, value=5)
#     [1] Row
#         [0] Str(int, name='interactive00198')

# %%
interactive_panel[0]
# Out:
# Column
#     [0] IntSlider(end=15, name='x', start=-5, value=5)

# %%
interactive_panel[1]
# Out:
# Row
#     [0] Str(int, name='interactive00198')

# %%
blast_results = pd.read_csv("/Users/cheyennebrouwer/Documents/23-24/Kwartaal_2/Data_Dashboards/Bioclear/wetransfer_ngs-data_2023-11-14_1231/NGS data/blast_results.txt", sep=",", header=0,
                       index_col=0)
pd_blast = pd.DataFrame(blast_results)
print(pd_blast)
# Out:
#            % identity                          specie
# Query id
# Zotu1         100.000    Arthrobacter nitrophenolicus
# Zotu2          99.765    Arthrobacter nitrophenolicus
# Zotu3          98.812     Methylothermalis aethiopiae
# Zotu4          99.050     Methylothermalis aethiopiae
# Zotu5          98.575     Methylothermalis aethiopiae
# ...               ...                             ...
# Zotu44396      99.061       Nocardioides marinisabuli
# Zotu44397      99.103                  Massilia rubra
# Zotu44398      99.552          Luteolibacter arcticus
# Zotu44399      93.080  Chthoniobacter flavus Ellin428
# Zotu44400      92.453           Litorilinea aerophila
#
# [44338 rows x 2 columns]

# %%
taxonomy = pd.read_csv("/Users/cheyennebrouwer/Documents/23-24/Kwartaal_2/Data_Dashboards/Bioclear/"
                       "wetransfer_ngs-data_2023-11-14_1231/NGS data/ASV_taxonomy.txt", sep="	", header=0,
                       index_col=0)

# %%
counts = pd.read_csv("/Users/cheyennebrouwer/Documents/23-24/Kwartaal_2/Data_Dashboards/Bioclear/wetransfer_ngs-data_2023-11-14_1231/NGS data/ASV_counts.txt", sep="	", header=0,
                       index_col=0)

# %%
fasta_file = pd.read_csv("/Users/cheyennebrouwer/Documents/23-24/Kwartaal_2/Data_Dashboards/Bioclear/wetransfer_ngs-data_2023-11-14_1231/NGS data/ASV.fa", sep="	", header=0,
                       index_col=0)

# %%
mapping = pd.read_csv("/Users/cheyennebrouwer/Documents/23-24/Kwartaal_2/Data_Dashboards/Bioclear/wetransfer_ngs-data_2023-11-14_1231/Mapping.txt", sep="	", header=0,
                       index_col=0)

# %%
# search_bar = pn.widgets.TextInput(name= "Zotu/bacteria id", placeholder = "Type Zotu or bacteria id: ")
#
# def filter_data(query_id):
#     if query_id:  # select the desired zotu from the dataframe
#         filtered_data = blast_results[blast_results["Query id"].str.contains(query_id, case = False)]
#     else:
#         filtered_data = blast_results  # return the entire dataframe if zotu is not present
#     return filtered_data()
#
# def update_display(event):
#     query_id = search_bar.value
#     filtered_data = filter_data(query_id)
#     display_table.object = filtered_data
#
# # Create a panel widget for displaying information
# display_table = pn.pane.DataFrame(blast_results.head())
#
# # Set up the callback to update the display when the query id changes
# search_bar.param.watch(update_display, 'value')
#
# # Create the layout
# layout = pn.Column(
#     "## Query Data Search",
#     search_bar,
#     display_table
# )
#
# # Serve the app
# pn.serve(layout)
# Out:
# Launching server at http://localhost:53534

# %%
import panel as pn
import pandas as pd

# Sample data (replace this with your actual data)
data = {
    'Query id': ['Zotu1', 'Zotu2', 'Zotu3', 'Zotu4', 'Zotu5', 'Zotu6'],
    '% identity': [100.0, 99.765, 98.812, 99.05, 98.575, 99.103],
    'Species': ['Arthrobacter nitrophenolicus', 'Arthrobacter nitrophenolicus',
                'Methylothermalis aethiopiae', 'Methylothermalis aethiopiae',
                'Methylothermalis aethiopiae', 'Bacillus oryzisoli']
}

df = pd.DataFrame(data)
print(df)
# Create a search bar
search_bar = pn.widgets.TextInput(placeholder='Enter Query id...')

# Create a function to filter data based on the query id
def filter_data(query_id):
    if query_id:
        filtered_data = df[df['Query id'].str.contains(query_id, case=False)]
    else:
        filtered_data = df
    return filtered_data

# Create a function to update the displayed information based on the query id
def update_display(event):
    query_id = search_bar.value
    filtered_data = filter_data(query_id)
    display_table.object = filtered_data

# Create a panel widget for displaying information
display_table = pn.pane.DataFrame(df)

# Set up the callback to update the display when the query id changes
search_bar.param.watch(update_display, 'value')

# Create the layout
layout = pn.Column(
    "## Query Data Search",
    search_bar,
    display_table
)

# Serve the app
pn.serve(layout)
# Out:
#   Query id  % identity                       Species
# 0    Zotu1     100.000  Arthrobacter nitrophenolicus
# 1    Zotu2      99.765  Arthrobacter nitrophenolicus
# 2    Zotu3      98.812   Methylothermalis aethiopiae
# 3    Zotu4      99.050   Methylothermalis aethiopiae
# 4    Zotu5      98.575   Methylothermalis aethiopiae
# 5    Zotu6      99.103            Bacillus oryzisoli
# Launching server at http://localhost:54889

# %%
taxonomy_levels = dict(zip(["d", "p", "c", "o", "f", "g", "s"], ["domain", "phylum", "class", "order", "family", "genus", "species"]))

class Node:
    def __init__(self, name, tax_level=None, counts={}): # counts is dict van sample en hoeveelheid
        self.name = name
        self.level = tax_level
        self.children = []
        self.parent = None
        self.zotus = []

    def add_child(self, child):
        self.children.append(child)
        child.parent = self

    def __repr__(self):
        first_zotu = "None" if len(self.zotus) == 0 else self.zotus[0]
        parent_name = "None" if self.parent is None else self.parent.name
        return f"\nNode name={self.name}; parent={parent_name}; children={len(self.children)}; zotus={len(self.zotus)}; {self.zotus}"

class Tree:
    def __init__(self):
        self.root = Node("root", "root")
        self.nodes = dict()
        self.nodes["root"] = self.root

    def add_lineage_str(self, lineage_str):
        #Zotu1  d:Bacteria,p:Actinobacteriota,c:Actinobacteria,o:Micrococcales,f:Micrococcaceae
        zotu, lineage = lineage_str.split("\t")
        lineage = lineage.split(",")
        parent = self.root
        for node_str in lineage:
            level, name = node_str.split(":")
            if name not in self.nodes:
                node = Node(name, taxonomy_levels[level])
                parent.add_child(node)
                node.parent = parent
                parent = node
                self.nodes[name] = node
            else:
                parent = self.nodes[name]
        #last node gets zotu annotated
        self.nodes[name].zotus.append(zotu)

    def __repr__(self):
        return f"Tree: {''.join([n.__repr__() for n in self.nodes.values()])}"

if __name__ == "__main__":
    tree = Tree()
    tree.add_lineage_str("Zotu3	d:Bacteria,p:Proteobacteria,c:Alphaproteobacteria") #,o:Micrococcales,f:Micrococcaceae")
    tree.add_lineage_str("Zotu7	d:Bacteria,p:Bacteroidota,c:Bacteroidia") #,o:Rhizobiales,f:Methyloligellaceae,g:uncultured")
    tree.add_lineage_str("Zotu6	d:Bacteria,p:Firmicutes,c:Bacilli") #,f:Bacillaceae,g:Bacillus")
    tree.add_lineage_str("Zotu9	d:Bacteria,p:Proteobacteria,c:Alphaproteobacteria") #,o:Rhizobiales,f:Methyloligellaceae,g:uncultured")
    print(tree)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 49
#      47 if __name__ == "__main__":
#      48     tree = Tree()
# ---> 49     tree.add_lineage_str("Zotu1 d:Bacteria,p:Actinobacteriota,c:Actinobacteria") #,o:Micrococcales,f:Micrococcaceae")
#      50     tree.add_lineage_str("Zotu5 d:Bacteria,p:Proteobacteria,c:Alphaproteobacteria") #,o:Rhizobiales,f:Methyloligellaceae,g:uncultured")
#      51     tree.add_lineage_str("Zotu6 d:Bacteria,p:Firmicutes,c:Bacilli,o:Bacillales") #,f:Bacillaceae,g:Bacillus")
#
# Cell In[13], line 28, in Tree.add_lineage_str(self, lineage_str)
#      26 def add_lineage_str(self, lineage_str):
#      27     #Zotu1  d:Bacteria,p:Actinobacteriota,c:Actinobacteria,o:Micrococcales,f:Micrococcaceae
# ---> 28     zotu, lineage = lineage_str.split("\t")
#      29     lineage = lineage.split(",")
#      30     parent = self.root
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
def __str__(self):
    newick = self._newick(self.root)
    newick.extend(';')
    return ''.join(newick)

def _newick(self, node, newick=[]):
    if len(node.children) > 0:
        newick.extend('(')
        for child in node.children:
            newick = self._newick(child, newick)
        if newick[-1] == ',':
            newick = newick[:-1]
        newick.extend(')')
    else:
        newick.extend(node.name)
        newick.extend(',')
    return newick

# %%
import panel as pn
from panel.interact import interact
pn.extension()

pn.Row("A", "B", "C", background="Gray")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4e75ed55-17f7-4ff7-868d-45d6e3d4d017'>
#   <div id="c5af76e3-c03b-4207-892d-af8565ec093b" data-root-id="4e75ed55-17f7-4ff7-868d-45d6e3d4d017" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e6d9511e-355f-4b5e-9636-25ec7fa0c9aa":{"version":"3.3.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4e75ed55-17f7-4ff7-868d-45d6e3d4d017"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"d37d95e4-c888-44cc-b92a-69b8c05595fd","attributes":{"plot_id":"4e75ed55-17f7-4ff7-868d-45d6e3d4d017","comm_id":"419c9a5a5b03455ca5611131b25279e1","client_comm_id":"a006f62999c948e68e1cac401858a922"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"e6d9511e-355f-4b5e-9636-25ec7fa0c9aa","roots":{"4e75ed55-17f7-4ff7-868d-45d6e3d4d017":"c5af76e3-c03b-4207-892d-af8565ec093b"},"root_ids":["4e75ed55-17f7-4ff7-868d-45d6e3d4d017"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# /var/folders/fq/v1shktmd5m16q3m70yydb1rc0000gn/T/ipykernel_89403/51487128.py:5: PanelDeprecationWarning: "Row(..., background='Gray')" is deprecated and will be removed in version 1.4, use "Row(..., styles={'background': 'Gray'})" instead.
#   pn.Row("A", "B", "C", background="Gray")
# Row(background='Gray', styles={'background': 'Gray'})
#     [0] Markdown(str)
#     [1] Markdown(str)
#     [2] Markdown(str)

# %%
pn.Column("A", "B", "C")
# Out:
# Column
#     [0] Markdown(str)
#     [1] Markdown(str)
#     [2] Markdown(str)

# %%
slider = pn.widgets.IntSlider(start=1, end=10, value=5, name="slider widget")

def multiply(x):
    return x*x

# Use interact function correctly
# interact(multiply, x=slider)

# Display the panel
pn.Row(interact(multiply, x=slider)).show()
# Out:
# Row
#     [0] Column
#         [0] Column
#             [0] IntSlider(end=10, name='slider widget', start=1, value=6)
#         [1] Row
#             [0] Str(int, name='interactive01017')

# %%
def f(x):
    return x*x

interact(f, x=(1,10)).show()
# Out:
# Launching server at http://localhost:61915

# %%
@interact(x=(1,10))
def f(x):
    return x*x

f.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 @interact(x=["a","b","c"])
# ----> 2 def f(x):
#       3     return x*x
#       5 f.show()
#
# File ~/Documents/23-24/Kwartaal_2/Data_Dashboards/lib/python3.10/site-packages/panel/interact.py:346, in _InteractFactory.__call__(self, _InteractFactory__interact_f, **kwargs)
#     338     raise ValueError('A function cannot have "throttled" as an argument')
#     340 # positional arg support in: https://gist.github.com/8851331
#     341 # Handle the cases 1 and 2
#     342 # 1. interact(f, **kwargs)
#     343 # 2. @interact
#     344 #    def f(*args, **kwargs):
#     345 #        ...
# --> 346 w = self.widget(f)
#     347 try:
#     348     f.widget = w
#
# File ~/Documents/23-24/Kwartaal_2/Data_Dashboards/lib/python3.10/site-packages/panel/interact.py:269, in _InteractFactory.widget(self, f)
#     256 def widget(self, f):
#     257     """
#     258     Return an interactive function widget for the given function.
#     259     The widget is only constructed, not displayed nor attached to
#    (...)
#     267         The function to which the interactive widgets are tied.
#     268     """
# --> 269     return self.cls(f, self.opts, **self.kwargs)
#
# File ~/Documents/23-24/Kwartaal_2/Data_Dashboards/lib/python3.10/site-packages/panel/interact.py:103, in interactive.__init__(self, object, params, **kwargs)
#     101     widgets.append(('manual', Button(name=self.manual_name)))
#     102 self._widgets = OrderedDict(widgets)
# --> 103 pane = self.object(**self.kwargs)
#     104 if isinstance(pane, Viewable):
#     105     self._pane = pane
#
# Cell In[42], line 3, in f(x)
#       1 @interact(x=["a","b","c"])
#       2 def f(x):
# ----> 3     return x*x
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
import panel as pn
import pandas as pd
import hvplot.pandas

data = [
    "Number1 d:Bacteria,p:Actinobacteriota,c:Actinobacteria,o:Micrococcales,f:Micrococcaceae",
    "Number2 d:Bacteria,p:Proteobacteria,c:Alphaproteobacteria,o:Rhizobiales,f:Methyloligellaceae,g:uncultured",
    "Number5 d:Bacteria,p:Firmicutes,c:Bacilli,o:Bacillales,f:Bacillaceae,g:Bacillus"
]

parsed_data = []

for entry in data:
    parts = entry.split(' ')
    number = parts[0]
    taxonomy_info = {item.split(':')[0]: item.split(':')[1] for item in parts[1:]}
    parsed_data.append({"Number": number, "Taxonomy": taxonomy_info})


df = pd.DataFrame(parsed_data)

# Create a list of unique taxonomy levels
taxonomy_levels = set(item for sublist in df['Taxonomy'].apply(lambda x: x.keys()).tolist() for item in sublist)

# Create a dropdown widget for taxonomy levels
taxonomy_dropdown = pn.widgets.Select(options=list(taxonomy_levels), value='p', name='Taxonomy Level')

def update_bar_chart(taxonomy_level):
    counts = df['Taxonomy'].apply(lambda x: x.get(taxonomy_level, 'unknown')).value_counts()
    bar_chart = counts.hvplot.bar(title=f'Counts of {taxonomy_level.capitalize()}').opts(
        hooks=[lambda x: x.opts(tools=['tap'], active_tools=['tap'])]
    )
    return bar_chart


@pn.depends(taxonomy_level=taxonomy_dropdown.param.value)
def update_app(taxonomy_level):
    return update_bar_chart(taxonomy_level)

# Link the selections between the bar chart and the dropdown
linked_selections = pn.panel(df.hvplot.table(selected=[]))  # Create an empty table to hold the linked selections
pn.links.link_selections(update_bar_chart('p'), linked_selections).servable()
# Out:
# WARNING:param.main: selected option not found for table plot with bokeh; similar options include: ['selectable']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 44
#      42 # Link the selections between the bar chart and the dropdown
#      43 linked_selections = pn.panel(df.hvplot.table(selected=[]))  # Create an empty table to hold the linked selections
# ---> 44 pn.links.link_selections(update_bar_chart('p'), linked_selections).servable()
#
# AttributeError: module 'panel.links' has no attribute 'link_selections'

# %%
# try to make a horizontal bar graph with Domain
taxonomy_data = pd.read_csv("/Users/cheyennebrouwer/Documents/23-24/Kwartaal_2/Data_Dashboards/Bioclear/wetransfer_ngs-data_2023-11-14_1231/NGS data/ASV_taxonomy.txt", sep="	", header= None,index_col=0)
dataframe_bargraph = pd.DataFrame(taxonomy_data)
dataframe_bargraph

ax = dataframe_bargraph.barh
# Out:
#                                                            1
# 0
# Zotu1      d:Bacteria,p:Actinobacteriota,c:Actinobacteria...
# Zotu5      d:Bacteria,p:Proteobacteria,c:Alphaproteobacte...
# Zotu6      d:Bacteria,p:Firmicutes,c:Bacilli,o:Bacillales...
# Zotu4      d:Bacteria,p:Proteobacteria,c:Alphaproteobacte...
# Zotu2      d:Bacteria,p:Actinobacteriota,c:Actinobacteria...
# ...                                                      ...
# Zotu44396  d:Bacteria,p:Actinobacteriota,c:Actinobacteria...
# Zotu44398  d:Bacteria,p:Verrucomicrobiota,c:Verrucomicrob...
# Zotu44397  d:Bacteria,p:Proteobacteria,c:Gammaproteobacte...
# Zotu44399  d:Bacteria,p:Verrucomicrobiota,c:Verrucomicrob...
# Zotu44400  d:Bacteria,p:Chloroflexi,c:Anaerolineae,o:Cald...
#
# [44400 rows x 1 columns]
